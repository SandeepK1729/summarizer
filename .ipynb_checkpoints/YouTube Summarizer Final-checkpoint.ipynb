# %%
# !pip install youtube_transcript_api transformers google_trans_new gtts pygame googletrans pillow
# Out:
# Requirement already satisfied: youtube_transcript_api in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (0.4.4)
# Requirement already satisfied: transformers in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (4.22.1)
# Requirement already satisfied: google_trans_new in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (1.1.9)
# Requirement already satisfied: gtts in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (2.2.4)
# Requirement already satisfied: pygame in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (2.1.2)
# Requirement already satisfied: googletrans in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (3.0.0)
# Requirement already satisfied: pillow in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (9.2.0)
# Requirement already satisfied: requests in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (from youtube_transcript_api) (2.28.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (from transformers) (0.12.1)
# Requirement already satisfied: filelock in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (from transformers) (3.7.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (from transformers) (2022.9.13)
# Requirement already satisfied: numpy>=1.17 in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (from transformers) (1.23.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (from transformers) (4.64.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.9.0 in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (from transformers) (0.9.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (from transformers) (21.3)
# Requirement already satisfied: click in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (from gtts) (8.1.3)
# Requirement already satisfied: six in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (from gtts) (1.16.0)
# Requirement already satisfied: httpx==0.13.3 in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (from googletrans) (0.13.3)
# Requirement already satisfied: httpcore==0.9.* in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (from httpx==0.13.3->googletrans) (0.9.1)
# Requirement already satisfied: chardet==3.* in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (from httpx==0.13.3->googletrans) (3.0.4)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (from httpx==0.13.3->googletrans) (1.5.0)
# Requirement already satisfied: hstspreload in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (from httpx==0.13.3->googletrans) (2022.9.1)
# Requirement already satisfied: certifi in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (from httpx==0.13.3->googletrans) (2022.6.15.1)
# Requirement already satisfied: sniffio in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (from httpx==0.13.3->googletrans) (1.3.0)
# Requirement already satisfied: idna==2.* in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (from httpx==0.13.3->googletrans) (2.10)
# Requirement already satisfied: h2==3.* in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans) (3.2.0)
# Requirement already satisfied: h11<0.10,>=0.8 in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans) (0.9.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans) (3.0.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub<1.0,>=0.9.0->transformers) (4.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: colorama in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (from tqdm>=4.27->transformers) (0.4.5)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (from requests->youtube_transcript_api) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (from requests->youtube_transcript_api) (1.26.9)

# %%
from tkinter import *
from youtube_transcript_api import YouTubeTranscriptApi as yta
import random
from google_trans_new import google_translator  
translator = google_translator()  
from gtts import gTTS #Import Google Text to Speech
from IPython.display import Audio 
import pygame
pygame.mixer.init()
from PIL import Image,ImageDraw,ImageFont,ImageTk
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.10.4)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
path = "C:\\Users\\sande\\OneDrive\\Desktop\\surya"

# %%
import tkinter as tk
ws = Tk()
ws.title("Summary Project")
ws.geometry("400x450")
ws['bg']='RoyalBlue3'

image1 = Image.open(f'{path}\\scc.jpg')
test = ImageTk.PhotoImage(image1)

label1 = tk.Label(image=test)
label1.image = test

# Position image
label1.place(x=1, y=1)


global sound_file

myfile = open(f'{path}\\summary.txt', "r")
myline = myfile.readline()
#print(myline)
myfile.close()

def youtube_link():
    name = Label(ws, text = " Enter Link ",bg='lavender',font=('TimesNewRoman',10,'bold'),borderwidth=2,relief='solid')
    name.place(x = 30,y = 50)  
    e1 = Entry(ws)
    e1.place(x = 120, y = 50)
    e1.get()
    def on_change(e1):
        global link
        global c
        link = e1.widget.get()
        a=link.find('=')
        b=link.find('&')
        c=link[a+1:b]

        vid_id = c
        data=yta.get_transcript(vid_id)

        transcript=''
        for value in data:
            for key,val in value.items():
                if key=='text':
                    transcript+=val + ", "
        
        l1=transcript.splitlines()
        global final_tra1
        final_tra1=" ".join(l1)
        
        print(final_tra1)

    e1.bind("<Return>", on_change)
    



def english():
    txtarea.delete('1.0', END)
    txtarea.insert(tk.END, myline )
    
    r1 = random.randint(1,10000000)
    r2 = random.randint(1,10000000)
 
    
    
    tts = gTTS(myline,lang='en-IN') #Provide the string to convert to speech
    sound_file = str(r2)+"SUMMARY"+str(r1) +".mp3"
    tts.save(sound_file) 
    Audio(sound_file, autoplay=False)
    #os.remove(sound_file)
    def play():
            pygame.mixer.music.load(sound_file)
            pygame.mixer.music.play(loops=0)

    def stop():
            pygame.mixer.music.stop()

    play_button = Button(ws, text="  Play  ", font=("TimesNewRoman", 12), command=play,bg='lavender blush',borderwidth=2,relief='solid')
   
    play_button.pack(pady=20)
    play_button.place(x=250, y=215)
    #play_button.grid(row = 25, column = 0)
    
    


def hindi():
    txtarea.delete('1.0', END)
    translate_text = translator.translate( myline  , lang_src='en', lang_tgt='hi')  
    txtarea.insert(tk.END,translate_text )

    r1 = random.randint(1,10000000)
    r2 = random.randint(1,10000000)
    sound_file = str(r2)+"SUMMARY"+str(r1) +".mp3"
    
    tts = gTTS(translate_text) #Provide the string to convert to speech
    tts.save(sound_file) #save the string converted to speech as a .wav file

    Audio(sound_file, autoplay=False)

    def play():
            pygame.mixer.music.load(sound_file)
            pygame.mixer.music.play(loops=0)

    def stop():
            pygame.mixer.music.stop()

    play_button = Button(ws, text="  Play  ", font=("TimesNewRoman", 12), command=play,bg='lavender blush',borderwidth=2,relief='solid')
   
    play_button.pack(pady=20)
    play_button.place(x=250, y=280)


def marathi():
    txtarea.delete('1.0', END)
    translate_text = translator.translate( myline  , lang_src='en', lang_tgt='mr')  
    txtarea.insert(tk.END,translate_text) 

    r1 = random.randint(1,10000000)
    r2 = random.randint(1,10000000)
    sound_file = str(r2)+"SUMMARY"+str(r1) +".mp3"
    
    tts = gTTS(translate_text) #Provide the string to convert to speech
    tts.save(sound_file)
    Audio(sound_file, autoplay=False)

    def play():
            pygame.mixer.music.load(sound_file)
            pygame.mixer.music.play(loops=0)

    def stop():
            pygame.mixer.music.stop()

    play_button = Button(ws, text="  Play  ", font=("Helvetica", 12), command=play,bg='lavender blush',borderwidth=2,relief='solid')
 
    play_button.pack(pady=20)
    play_button.place(x=250, y=345)
    #btn1 = Button(ws, text ="New", command = play_button.destroy)
    #btn1.pack(pady = 10)
    

def gujurati():
    txtarea.delete('1.0', END)
    translate_text = translator.translate( myline , lang_src='en', lang_tgt='gu')  
    txtarea.insert(tk.END,translate_text)

    r1 = random.randint(1,10000000)
    r2 = random.randint(1,10000000)
    sound_file = str(r2)+"SUMMARY"+str(r1) +".mp3"
    
    tts = gTTS(translate_text) #Provide the string to convert to speech
    tts.save(sound_file)
    Audio(sound_file, autoplay=False)

    def play():
            pygame.mixer.music.load(sound_file)
            pygame.mixer.music.play(loops=0)

    def stop():
            pygame.mixer.music.stop()

    def destroy():
        play().destroy()
    
    play_button = Button(ws, text="  Play  ", font=("Helvetica", 12), command=play,bg='lavender blush',borderwidth=2,relief='solid')
   
    play_button.pack(pady=20)
    play_button.place(x=250, y=410)
    #btn1 = Button(ws, text ="New", command = play_button.destroy)
    #btn1.pack(pady = 10)
    
    
def german():
    txtarea.delete('1.0', END)
    translate_text = translator.translate( myline  , lang_src='en', lang_tgt='de')  
    txtarea.insert(tk.END,translate_text)

    r1 = random.randint(1,10000000)
    r2 = random.randint(1,10000000)
    sound_file = str(r2)+"SUMMARY"+str(r1) +".mp3"
    
    tts = gTTS(translate_text) #Provide the string to convert to speech
    tts.save(sound_file)
    Audio(sound_file, autoplay=False)


    def play():
            pygame.mixer.music.load(sound_file)
            pygame.mixer.music.play(loops=0)

    def stop():
            pygame.mixer.music.stop()

    play_button = Button(ws, text="  Play  ", font=("Helvetica", 12), command=play,bg='lavender blush',borderwidth=2,relief='solid')
    
    play_button.pack(pady=20)

    play_button.place(x=250, y=475)
    
    #btn1 = Button(ws, text ="New", command = play_button.destroy)
    #btn1.pack(pady = 10)

def bengali():
    txtarea.delete('1.0', END)
    translate_text = translator.translate( myline  , lang_src='en', lang_tgt='bn')  
    txtarea.insert(tk.END,translate_text)

    r1 = random.randint(1,10000000)
    r2 = random.randint(1,10000000)
    sound_file = str(r2)+"SUMMARY"+str(r1) +".mp3"
    
    tts = gTTS(translate_text) #Provide the string to convert to speech
    tts.save(sound_file)
    Audio(sound_file, autoplay=False)

    def play():
            pygame.mixer.music.load(sound_file)
            pygame.mixer.music.play(loops=0)

    def stop():
            pygame.mixer.music.stop()

    play_button = Button(ws, text="  Play  ", font=("Helvetica", 12), command=play,bg='lavender blush',borderwidth=2,relief='solid')
    
    play_button.pack(pady=20)
    play_button.place(x=1340, y=215) 

    #btn1 = Button(ws, text ="New", command = play_button.destroy)
    #btn1.pack(pady = 10)

def punjabi():
    txtarea.delete('1.0', END)
    translate_text = translator.translate( myline  , lang_src='en', lang_tgt='pa')  
    txtarea.insert(tk.END,translate_text)

    r1 = random.randint(1,10000000)
    r2 = random.randint(1,10000000)
    sound_file = str(r2)+"SUMMARY"+str(r1) +".mp3"
    
    tts = gTTS(translate_text) #Provide the string to convert to speech
    tts.save(sound_file)
    Audio(sound_file, autoplay=False)

    def play():
            pygame.mixer.music.load(sound_file)
            pygame.mixer.music.play(loops=0)

    def stop():
            pygame.mixer.music.stop()

    play_button = Button(ws, text="  Play  ", font=("Helvetica", 12), command=play,bg='lavender blush',borderwidth=2,relief='solid')
    
    play_button.pack(pady=20)
    play_button.place(x=1340, y=280)    

    #btn1 = Button(ws, text ="New", command = play_button.destroy)
    #btn1.pack(pady = 10)
    
    
def tamil():
    txtarea.delete('1.0', END)
    translate_text = translator.translate( myline  , lang_src='en', lang_tgt='ta')  
    txtarea.insert(tk.END,translate_text)

    r1 = random.randint(1,10000000)
    r2 = random.randint(1,10000000)
    sound_file = str(r2)+"SUMMARY"+str(r1) +".mp3"
    
    tts = gTTS(translate_text) #Provide the string to convert to speech
    tts.save(sound_file)
    Audio(sound_file, autoplay=False)

    def play():
            pygame.mixer.music.load(sound_file)
            pygame.mixer.music.play(loops=0)

    def stop():
            pygame.mixer.music.stop()

    play_button = Button(ws, text="  Play  ", font=("Helvetica", 12), command=play,bg='lavender blush',borderwidth=2,relief='solid')

    play_button.pack(pady=20)
    play_button.place(x=1340, y=345)    


    
def telegu():
    txtarea.delete('1.0', END)
    translate_text = translator.translate( myline  , lang_src='en', lang_tgt='te')  
    txtarea.insert(tk.END,translate_text)

    r1 = random.randint(1,10000000)
    r2 = random.randint(1,10000000)
    sound_file = str(r2)+"SUMMARY"+str(r1) +".mp3"
    
    tts = gTTS(translate_text) #Provide the string to convert to speech
    tts.save(sound_file)
    Audio(sound_file, autoplay=False)

    def play():
            pygame.mixer.music.load(sound_file)
            pygame.mixer.music.play(loops=0)

    def stop():
            pygame.mixer.music.stop()

    play_button = Button(ws, text="  Play  ", font=("Helvetica", 12), command=play,bg='lavender blush',borderwidth=2,relief='solid')
    
    play_button.pack(pady=20)
    play_button.place(x=1340, y=410)


def french():
    txtarea.delete('1.0', END)
    translate_text = translator.translate( myline  , lang_src='en', lang_tgt='fr')  
    txtarea.insert(tk.END,translate_text)

    r1 = random.randint(1,10000000)
    r2 = random.randint(1,10000000)
    sound_file = str(r2)+"SUMMARY"+str(r1) +".mp3"
    
    tts = gTTS(translate_text) #Provide the string to convert to speech
    tts.save(sound_file)
    Audio(sound_file, autoplay=False)

    def play():
            pygame.mixer.music.load(sound_file)
            pygame.mixer.music.play(loops=0)

    def stop():
            pygame.mixer.music.stop()

    play_button = Button(ws, text="  Play  ", font=("Helvetica", 12), command=play,bg='lavender blush',
                         borderwidth=2,relief='solid')
   
    play_button.pack(pady=20)
    play_button.place(x=1340, y=475)


def transcript():
    txtarea.delete('1.0', END)
    txtarea.insert(tk.END,final_tra1 )
    
    r1 = random.randint(1,10000000)
    r2 = random.randint(1,10000000)
 
    
    
    tts = gTTS(final_tra1,lang='en-uk') #Provide the string to convert to speech
    sound_file = str(r2)+"SUMMARY"+str(r1) +".mp3"
    tts.save(sound_file) 
    Audio(sound_file, autoplay=False)
    #os.remove(sound_file)
    def play():
            pygame.mixer.music.load(sound_file)
            pygame.mixer.music.play(loops=0)

    def stop():
            pygame.mixer.music.stop()

    play_button = Button(ws, text="Play", font=("Helvetica", 12), command=play)
   
    play_button.pack(pady=20)
    #play_button.place(x=20, y=300)
    pla_button.grid(row = 25, column = 0)
    

    

def stop():
        pygame.mixer.music.stop()    
        


language = [ "   Hindi   "," Marathi "," Gujurati "," German "," Bengali "," Punjabi ","   Tamil   ","  Telegu  ","  French  "," English "]


btn1 = Button(ws, text=language[0], command=hindi,font=("TimesNewRoman", 12),bg='lavender blush',borderwidth=2,relief='solid')
btn1.pack(side=tk.LEFT,pady=20)
btn1.place(x=160, y=280)

btn2 = Button(ws, text=language[1], command=marathi,font=("TimesNewRoman", 12),bg='lavender blush',borderwidth=2,relief='solid')
btn2.pack(side=tk.LEFT,pady=20)
btn2.place(x=160, y=345)

btn3 = Button(ws, text=language[2], command=gujurati,font=("TimesNewRoman", 12),bg='lavender blush',borderwidth=2,relief='solid')
btn3.pack(side=tk.LEFT,pady=20)
btn3.place(x=160, y=410)


btn4 = Button(ws, text=language[3], command=german,font=("TimesNewRoman", 12),bg='lavender blush',borderwidth=2,relief='solid')
btn4.pack(side=tk.LEFT,pady=20)
btn4.place(x=160, y=475)


btn5 = Button(ws, text=language[4], command=bengali, font=("TimesNewRoman", 12),bg='lavender blush',borderwidth=2,relief='solid')
btn5.pack(side=tk.LEFT,pady=20)
btn5.place(x=1250, y=215)


btn6 = Button(ws, text=language[5], command=punjabi,font=("TimesNewRoman", 12),bg='lavender blush',borderwidth=2,relief='solid')
btn6.pack(side=tk.LEFT,pady=20)
btn6.place(x=1250, y=280)

btn7 = Button(ws, text=language[6], command=tamil,font=("TimesNewRoman", 12),bg='lavender blush',borderwidth=2,relief='solid')
btn7.pack(side=tk.LEFT,pady=20)
btn7.place(x=1250, y=345)


btn8 = Button(ws, text=language[7], command=telegu,font=("TimesNewRoman", 12),bg='lavender blush',borderwidth=2,relief='solid')
btn8.pack(side=tk.LEFT,pady=20)
btn8.place(x=1250, y=410)




btn10 = Button(ws, text=language[8], command=french,font=("TimesNewRoman", 12),bg='lavender blush',borderwidth=2,relief='solid')
btn10.pack(side=tk.LEFT,pady=20)
btn10.place(x=1250, y=475)


btn11 = Button(ws, text=language[9],font=("TimesNewRoman", 12),bg='lavender blush', command=english,borderwidth=2,relief='solid')
btn11.pack(side=tk.LEFT,pady=20)
btn11.place(x=160, y=215)

#btn12 = Button(ws, text='Transcript', command=transcript,font=("TimesNewRoman", 12),bg='lavender blush',borderwidth=2,relief='solid')
#btn12.pack(side=tk.LEFT,pady=20)
#btn12.place(x=160, y=500)

stop_button = Button(ws, text="  Stop  ", command=stop,font=("TimesNewRoman", 14,'bold'),bg='lavender blush',borderwidth=2,relief='solid')
stop_button.pack(pady=20)
stop_button.place(x=650,y=565)
stop_button.font='bold'

txtarea = Text(ws,wrap=WORD,bg='lavender',font=("TimesNewRoman",11),width=90, height=20,borderwidth=4,relief='solid',padx=10,pady=10,spacing2=5)
txtarea.pack(pady=100)
txtarea.place(x=390,y=170)


label = Label(ws,text=' Transcript Summarizer ',bg='lavender',font=('TimesNewRoman',32,'bold'),borderwidth=3,relief='solid')
label.place(x=520,y=40)

get_link=Button(ws,command=youtube_link,text="  Link  ",font=("TimesNewRoman", 14,'bold'),bg='lavender blush',borderwidth=2,relief='solid')
get_link.pack(pady=20)
get_link.place(x=760,y=565)
#get_link=Button(ws,command=youtube_link,text="Get link").pack(side=RIGHT, expand=True, fill=X, padx=20)

ws.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\sande\AppData\Local\Temp\ipykernel_5996\2567936428.py", line 39, in on_change
#     data=yta.get_transcript(vid_id)
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\site-packages\youtube_transcript_api\_api.py", line 129, in get_transcript
#     return cls.list_transcripts(video_id, proxies, cookies).find_transcript(languages).fetch()
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\site-packages\youtube_transcript_api\_api.py", line 71, in list_transcripts
#     return TranscriptListFetcher(http_client).fetch(video_id)
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\site-packages\youtube_transcript_api\_transcripts.py", line 47, in fetch
#     self._extract_captions_json(self._fetch_video_html(video_id), video_id)
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\site-packages\youtube_transcript_api\_transcripts.py", line 59, in _extract_captions_json
#     raise TranscriptsDisabled(video_id)
# youtube_transcript_api._errors.TranscriptsDisabled:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=tiZFewofSL! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\sande\AppData\Local\Temp\ipykernel_5996\2567936428.py", line 90, in hindi
#     translate_text = translator.translate( myline  , lang_src='en', lang_tgt='hi')
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\site-packages\google_trans_new\google_trans_new.py", line 188, in translate
#     raise e
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\site-packages\google_trans_new\google_trans_new.py", line 152, in translate
#     response = json.loads(response)
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\json\decoder.py", line 340, in decode
#     raise JSONDecodeError("Extra data", s, end)
# json.decoder.JSONDecodeError: Extra data: line 1 column 2212 (char 2211)
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\sande\AppData\Local\Temp\ipykernel_5996\2567936428.py", line 90, in hindi
#     translate_text = translator.translate( myline  , lang_src='en', lang_tgt='hi')
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\site-packages\google_trans_new\google_trans_new.py", line 188, in translate
#     raise e
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\site-packages\google_trans_new\google_trans_new.py", line 152, in translate
#     response = json.loads(response)
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\json\decoder.py", line 340, in decode
#     raise JSONDecodeError("Extra data", s, end)
# json.decoder.JSONDecodeError: Extra data: line 1 column 2208 (char 2207)
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\sande\AppData\Local\Temp\ipykernel_5996\2567936428.py", line 39, in on_change
#     data=yta.get_transcript(vid_id)
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\site-packages\youtube_transcript_api\_api.py", line 129, in get_transcript
#     return cls.list_transcripts(video_id, proxies, cookies).find_transcript(languages).fetch()
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\site-packages\youtube_transcript_api\_api.py", line 71, in list_transcripts
#     return TranscriptListFetcher(http_client).fetch(video_id)
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\site-packages\youtube_transcript_api\_transcripts.py", line 47, in fetch
#     self._extract_captions_json(self._fetch_video_html(video_id), video_id)
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\site-packages\youtube_transcript_api\_transcripts.py", line 59, in _extract_captions_json
#     raise TranscriptsDisabled(video_id)
# youtube_transcript_api._errors.TranscriptsDisabled:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=tiZFewofSL! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\sande\AppData\Local\Temp\ipykernel_5996\2567936428.py", line 206, in bengali
#     translate_text = translator.translate( myline  , lang_src='en', lang_tgt='bn')
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\site-packages\google_trans_new\google_trans_new.py", line 188, in translate
#     raise e
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\site-packages\google_trans_new\google_trans_new.py", line 152, in translate
#     response = json.loads(response)
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\json\decoder.py", line 340, in decode
#     raise JSONDecodeError("Extra data", s, end)
# json.decoder.JSONDecodeError: Extra data: line 1 column 2189 (char 2188)
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\sande\AppData\Local\Temp\ipykernel_5996\2567936428.py", line 39, in on_change
#     data=yta.get_transcript(vid_id)
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\site-packages\youtube_transcript_api\_api.py", line 129, in get_transcript
#     return cls.list_transcripts(video_id, proxies, cookies).find_transcript(languages).fetch()
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\site-packages\youtube_transcript_api\_api.py", line 71, in list_transcripts
#     return TranscriptListFetcher(http_client).fetch(video_id)
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\site-packages\youtube_transcript_api\_transcripts.py", line 47, in fetch
#     self._extract_captions_json(self._fetch_video_html(video_id), video_id)
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\site-packages\youtube_transcript_api\_transcripts.py", line 59, in _extract_captions_json
#     raise TranscriptsDisabled(video_id)
# youtube_transcript_api._errors.TranscriptsDisabled:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=tiZFewofSL! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\sande\AppData\Local\Temp\ipykernel_5996\2567936428.py", line 90, in hindi
#     translate_text = translator.translate( myline  , lang_src='en', lang_tgt='hi')
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\site-packages\google_trans_new\google_trans_new.py", line 188, in translate
#     raise e
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\site-packages\google_trans_new\google_trans_new.py", line 152, in translate
#     response = json.loads(response)
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\json\decoder.py", line 340, in decode
#     raise JSONDecodeError("Extra data", s, end)
# json.decoder.JSONDecodeError: Extra data: line 1 column 2209 (char 2208)
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\sande\AppData\Local\Temp\ipykernel_5996\2567936428.py", line 145, in gujurati
#     translate_text = translator.translate( myline , lang_src='en', lang_tgt='gu')
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\site-packages\google_trans_new\google_trans_new.py", line 188, in translate
#     raise e
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\site-packages\google_trans_new\google_trans_new.py", line 152, in translate
#     response = json.loads(response)
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\json\decoder.py", line 340, in decode
#     raise JSONDecodeError("Extra data", s, end)
# json.decoder.JSONDecodeError: Extra data: line 1 column 2082 (char 2081)
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\sande\AppData\Local\Temp\ipykernel_5996\2567936428.py", line 234, in punjabi
#     translate_text = translator.translate( myline  , lang_src='en', lang_tgt='pa')
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\site-packages\google_trans_new\google_trans_new.py", line 188, in translate
#     raise e
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\site-packages\google_trans_new\google_trans_new.py", line 152, in translate
#     response = json.loads(response)
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\json\decoder.py", line 340, in decode
#     raise JSONDecodeError("Extra data", s, end)
# json.decoder.JSONDecodeError: Extra data: line 1 column 2094 (char 2093)
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\sande\AppData\Local\Temp\ipykernel_5996\2567936428.py", line 206, in bengali
#     translate_text = translator.translate( myline  , lang_src='en', lang_tgt='bn')
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\site-packages\google_trans_new\google_trans_new.py", line 188, in translate
#     raise e
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\site-packages\google_trans_new\google_trans_new.py", line 152, in translate
#     response = json.loads(response)
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\json\__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#   File "C:\Users\sande\AppData\Local\Programs\Python\Python310\lib\json\decoder.py", line 340, in decode
#     raise JSONDecodeError("Extra data", s, end)
# json.decoder.JSONDecodeError: Extra data: line 1 column 2186 (char 2185)

# %%
import googletrans
print(googletrans.LANGUAGES)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 import googletrans
#       2 print(googletrans.LANGUAGES)
#
# ModuleNotFoundError: No module named 'googletrans'
